# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
doc = pd.read_csv("sample.csv")

documents = np.array(doc)
print(documents)

vectorizer = TfidfVectorizer(use_idf=True)
X = vectorizer.fit_transform(documents.ravel())
#print(X)
# Out:
# [['indusind']
#  ['PAYTM  ']
#  ['PTM*PAYTM   ']
#  ...
#  ['TRINITY SERVICE STATIO']
#  ['VISAKHAM STEEL PLVISAKHAPA']
#  ['VISHAL FUELS']]

# %%
from scipy.spatial.distance import pdist, squareform
from scipy.spatial.distance import cdist
from Levenshtein import ratio
matrix = cdist(documents, documents, lambda x,y: ratio(x[0], y[0]))
df = pd.DataFrame(data=matrix, index=documents, columns=documents)
df
# Out:
#                                (indusind,)  (PAYTM  ,)  (PTM*PAYTM   ,)  \
# (indusind,)                            1.0    0.000000         0.000000
# (PAYTM  ,)                             0.0    1.000000         0.736842
# (PTM*PAYTM   ,)                        0.0    0.736842         1.000000
# (ONE97 COMMUNICATIONS L,)              0.0    0.206897         0.235294
# (PAYTM  ,)                             0.0    1.000000         0.736842
# ...                                    ...         ...              ...
# (TRAVEL CLUB,)                         0.0    0.222222         0.260870
# (TRINATH SERVICE STN   ,)              0.0    0.275862         0.352941
# (TRINITY SERVICE STATIO,)              0.0    0.206897         0.235294
# (VISAKHAM STEEL PLVISAKHAPA,)          0.0    0.242424         0.210526
# (VISHAL FUELS,)                        0.0    0.210526         0.166667
#
#                                (ONE97 COMMUNICATIONS L,)  (PAYTM  ,)  \
# (indusind,)                                     0.000000    0.000000
# (PAYTM  ,)                                      0.206897    1.000000
# (PTM*PAYTM   ,)                                 0.235294    0.736842
# (ONE97 COMMUNICATIONS L,)                       1.000000    0.206897
# (PAYTM  ,)                                      0.206897    1.000000
# ...                                                  ...         ...
# (TRAVEL CLUB,)                                  0.242424    0.222222
# (TRINATH SERVICE STN   ,)                       0.318182    0.275862
# (TRINITY SERVICE STATIO,)                       0.363636    0.206897
# (VISAKHAM STEEL PLVISAKHAPA,)                   0.208333    0.242424
# (VISHAL FUELS,)                                 0.235294    0.210526
#
#                                (NETFLIX224092000,)  (Indian Railway Caterin,)  \
# (indusind,)                               0.000000                   0.266667
# (PAYTM  ,)                                0.086957                   0.137931
# (PTM*PAYTM   ,)                           0.071429                   0.117647
# (ONE97 COMMUNICATIONS L,)                 0.210526                   0.090909
# (PAYTM  ,)                                0.086957                   0.137931
# ...                                            ...                        ...
# (TRAVEL CLUB,)                            0.148148                   0.181818
# (TRINATH SERVICE STN   ,)                 0.157895                   0.181818
# (TRINITY SERVICE STATIO,)                 0.210526                   0.181818
# (VISAKHAM STEEL PLVISAKHAPA,)             0.142857                   0.125000
# (VISHAL FUELS,)                           0.142857                   0.117647
#
#                                (GOOGLEPLAY  ,)  (BILL   000800100,)  \
# (indusind,)                           0.000000             0.000000
# (PAYTM  ,)                            0.526316             0.173913
# (PTM*PAYTM   ,)                       0.416667             0.214286
# (ONE97 COMMUNICATIONS L,)             0.235294             0.105263
# (PAYTM  ,)                            0.526316             0.173913
# ...                                        ...                  ...
# (TRAVEL CLUB,)                        0.260870             0.148148
# (TRINATH SERVICE STN   ,)             0.176471             0.210526
# (TRINITY SERVICE STATIO,)             0.176471             0.157895
# (VISAKHAM STEEL PLVISAKHAPA,)         0.210526             0.142857
# (VISHAL FUELS,)                       0.250000             0.214286
#
#                                (NETLFIX,)  ...  (SNAPECOM    ,)  \
# (indusind,)                      0.000000  ...         0.000000
# (PAYTM  ,)                       0.142857  ...         0.421053
# (PTM*PAYTM   ,)                  0.105263  ...         0.416667
# (ONE97 COMMUNICATIONS L,)        0.275862  ...         0.352941
# (PAYTM  ,)                       0.142857  ...         0.421053
# ...                                   ...  ...              ...
# (TRAVEL CLUB,)                   0.222222  ...         0.260870
# (TRINATH SERVICE STN   ,)        0.206897  ...         0.470588
# (TRINITY SERVICE STATIO,)        0.275862  ...         0.235294
# (VISAKHAM STEEL PLVISAKHAPA,)    0.181818  ...         0.263158
# (VISHAL FUELS,)                  0.210526  ...         0.250000
#
#                                (SNR SONS CHARITABLE TR,)  \
# (indusind,)                                     0.000000
# (PAYTM  ,)                                      0.206897
# (PTM*PAYTM   ,)                                 0.176471
# (ONE97 COMMUNICATIONS L,)                       0.363636
# (PAYTM  ,)                                      0.206897
# ...                                                  ...
# (TRAVEL CLUB,)                                  0.242424
# (TRINATH SERVICE STN   ,)                       0.363636
# (TRINITY SERVICE STATIO,)                       0.363636
# (VISAKHAM STEEL PLVISAKHAPA,)                   0.291667
# (VISHAL FUELS,)                                 0.294118
#
#                                (South Central Railway SECUNDERA,)  \
# (indusind,)                                              0.102564
# (PAYTM  ,)                                               0.105263
# (PTM*PAYTM   ,)                                          0.139535
# (ONE97 COMMUNICATIONS L,)                                0.188679
# (PAYTM  ,)                                               0.105263
# ...                                                           ...
# (TRAVEL CLUB,)                                           0.190476
# (TRINATH SERVICE STN   ,)                                0.226415
# (TRINITY SERVICE STATIO,)                                0.264151
# (VISAKHAM STEEL PLVISAKHAPA,)                            0.210526
# (VISHAL FUELS,)                                          0.186047
#
#                                (SRI VENKATESWARA ,)  (Talabat com DUBAI,)  \
# (indusind,)                                0.000000              0.000000
# (PAYTM  ,)                                 0.250000              0.250000
# (PTM*PAYTM   ,)                            0.206897              0.206897
# (ONE97 COMMUNICATIONS L,)                  0.307692              0.205128
# (PAYTM  ,)                                 0.250000              0.250000
# ...                                             ...                   ...
# (TRAVEL CLUB,)                             0.285714              0.285714
# (TRINATH SERVICE STN   ,)                  0.410256              0.153846
# (TRINITY SERVICE STATIO,)                  0.358974              0.256410
# (VISAKHAM STEEL PLVISAKHAPA,)              0.372093              0.139535
# (VISHAL FUELS,)                            0.275862              0.137931
#
#                                (TRAVEL CLUB,)  (TRINATH SERVICE STN   ,)  \
# (indusind,)                          0.000000                   0.000000
# (PAYTM  ,)                           0.222222                   0.275862
# (PTM*PAYTM   ,)                      0.260870                   0.352941
# (ONE97 COMMUNICATIONS L,)            0.242424                   0.318182
# (PAYTM  ,)                           0.222222                   0.275862
# ...                                       ...                        ...
# (TRAVEL CLUB,)                       1.000000                   0.363636
# (TRINATH SERVICE STN   ,)            0.363636                   1.000000
# (TRINITY SERVICE STATIO,)            0.303030                   0.727273
# (VISAKHAM STEEL PLVISAKHAPA,)        0.270270                   0.375000
# (VISHAL FUELS,)                      0.347826                   0.294118
#
#                                (TRINITY SERVICE STATIO,)  \
# (indusind,)                                     0.000000
# (PAYTM  ,)                                      0.206897
# (PTM*PAYTM   ,)                                 0.235294
# (ONE97 COMMUNICATIONS L,)                       0.363636
# (PAYTM  ,)                                      0.206897
# ...                                                  ...
# (TRAVEL CLUB,)                                  0.303030
# (TRINATH SERVICE STN   ,)                       0.727273
# (TRINITY SERVICE STATIO,)                       1.000000
# (VISAKHAM STEEL PLVISAKHAPA,)                   0.333333
# (VISHAL FUELS,)                                 0.235294
#
#                                (VISAKHAM STEEL PLVISAKHAPA,)  (VISHAL FUELS,)
# (indusind,)                                         0.000000         0.000000
# (PAYTM  ,)                                          0.242424         0.210526
# (PTM*PAYTM   ,)                                     0.210526         0.166667
# (ONE97 COMMUNICATIONS L,)                           0.208333         0.235294
# (PAYTM  ,)                                          0.242424         0.210526
# ...                                                      ...              ...
# (TRAVEL CLUB,)                                      0.270270         0.347826
# (TRINATH SERVICE STN   ,)                           0.375000         0.294118
# (TRINITY SERVICE STATIO,)                           0.333333         0.235294
# (VISAKHAM STEEL PLVISAKHAPA,)                       1.000000         0.473684
# (VISHAL FUELS,)                                     0.473684         1.000000
#
# [4084 rows x 4084 columns]

# %%
from sklearn_extra.cluster import KMedoids
kmedoids = KMedoids(n_clusters = 6, random_state = 0, metric = 'cosine').fit(df)
prediction_kmedoids = kmedoids.predict(df)
#prediction_kmedoids
from collections import defaultdict
d_kmedoids = defaultdict(list)
for i,p in enumerate(prediction_kmedoids):
    d_kmedoids[p].append(documents[i][0])
print(d_kmedoids)
# Out:
# ['GOOGLEPLAY  ', 'SWIGGY DASH 911311221', 'BOOKMYSHOW COM   124305400', 'BOOKMYSHOW  022560889', 'TPTUPOTHDRCARD   ', 'PASSPORTSEVAMOPSOBD   ', 'SWIGGY DASH 9113112212', 'CFMSANDOTHDRCARD ', 'GOOGLE PLAY APP CYBS S224092000', 'DREAM11 FANTASY  PU   GALURU', 'HARYANA CITY GAS ', 'HDFCERGOINS ', 'BOOKMYSHOW  02256088960', 'BHAGWATI TRANSFORMER  ', 'PAYU MONEY  ', 'GOOGLE PLAY SER CYBS S224092000', 'DLF MALL OF INDIA FOOD', 'PBRTOOTHDRCARD   ', 'STAR BAZAAR ', 'FORIGN LIQUOR    GAUTAM BU', 'EDCILDRCARD ', 'GODADDY INDIA DOMAINS ', 'DISCOVERY SALES  ', 'BOOKMYSHOW COM   1243054000', 'UPGOVTOTHDRCARD  ', 'METRO CASH AND CARRY I', 'URBAN COMPANY    GURUGRAM', 'SBCOTHERBANKDBCARDE   ', 'STAR BAZAAR ', 'MCDONALDS   ', 'DMART READY ', 'GOOGLE PAYMENTS INDIA ', 'MAGUNTA AGRO FARMS PVT', 'MAHAGVECPR  ', 'TNREGOTHDRCARD   ', 'UDEMY  ', 'UPPARIKSHAOTHDRCARD   ', 'MORE   ', 'FREECHARGE  ', 'PTM*PAYTM FASTAG ', 'MCDONALDS   ', 'METRO CASH AND CARRY I', 'DISCOVERYLIQUORHOUSE  ', 'ZARA 0841944', 'BPCL BP    BHUBANESW', 'GOOGLEWORKSP', '4019 D MART MULUND    ', 'METRO CASH AND CARRY I', 'A S M ABDUL CADER AND ', 'MORE  ', 'HALDI RAMS  ', 'MORE   ', 'SRI ARAVINDAR AND CO  ', 'MODEL SHOP  GAUTAM BU', 'BPCL BP INDIRAPURAM   ', 'FORIGN LIQUOR    GAUTAM BUDH', 'MCDONALDS   ', 'MS JAGDISH  ', 'JRM ASSOCIATES   DEHRADUN', 'HPCL R D MOTORS  ', 'MCDONALDS   ', '4035 DMART NAHAR ', 'DOLLY MOTORS', 'BOB CREDIT CARDS ', 'MODEL SHOP  ', 'ROYAL SUNDARAM EAPPS  ', 'GURUNANAK AUTOMOBILES ', 'RADHA AGENCIES   KANCHIPUR', 'PAWAN KUMAR AND CO    ', '5013 D MART S D ROAD  ', '5027 DMART BALANAGAR  ', 'R G SONS AND OTHERS   Gautam Bu', 'BPCL SHREE BAGYAM AGEN', 'RAMNATHJAISAWAL  ', '4143 D MART HINJEWADI ', 'MORE  ', 'BIG BAZAAR ', 'DMART  VADODARA', 'COMPASS GROUP INDIA SU', 'MAMAEARTH   ', 'RELIANCE FRESH   AHMEDABAD', '4043 D MART PALE AMBER', 'BAJAJALZGEN ', 'BP AGRICULTURE FARM 1 ', 'AIP*GODADDY INDIA DOMA', 'EMMAR FUEL PARK  ', 'STAR BAZAAR ', 'COCO RBI SQUARE   CI', 'ZARA 0841888', 'FKPAYMENTS  ', 'NAMDHARI AGRO FRESH   ', 'THIRUARUL   ', '5011 DMART KUSHAIGUDA ', 'GOOGLE WORKSPACE CYBS 224092000', 'HARDCASTLE RESTAURAN  ', '6301 DMART SALEM SALEM', '3951 D Mart DamanDAMAN', 'CRACKERS INDIA ALLOY  BARBIL', '4031 DMART VIRAR PALGHAR', '4154 D MART NIBM PUNE ', 'MCDONALDS   ', 'TPTUKOTHDRCARD   ', 'ZUDIO A UNIT OF TRENT ', 'SHRI RAM FUEL CENTRE  ', 'CITRUS PAY GO AIR', 'HIND AUTOMOBILES ', 'NRC AND SONS', 'DMART  ', 'MORE  ', 'TML*GOOGLE PAYMENTS IN', 'R G SONS AND OTHERS   ', 'KENDRIYA BHANDAR ', 'SBCOTHERBANKDBCARDO   ', '5604 D MART JAYANAGAR ', 'BP COCO KHARGHAR 2    NAVI MUMB', 'BPCL SHAHEED NANAK CHA', 'HALDIRAM.   ', '3811 D MART SHIVALIK  AHMEDABAD', '5029 DMART LAXMIPURAM WARANGAL', 'COLUMBIA ASIA    ', 'UPCL DEHRADUN    DEHRADUN', '4034 D MART KALYAN    ', 'CROMA  ', 'SRI MKR AND SONS ', 'MCDONALDS   ', 'DMART  ', 'SBPDCLRAPD  ', 'JAI HIND HIGHWAY ', 'BIG BAZAAR  ', 'CCA*BtoBCCA ', 'MC DONALDS  NAVI MUMB', 'RELIANCE FRESH   JAMSHEDPU', 'BAJAJ  ', 'COLUMBIA ASIA    ', 'KERALWATAX  ', 'ZUDIO A UNIT', '5022 DMART MADINAGUDA ', 'K PARAMASIVAN AND SONS', 'BtoBCCA', 'J R AMIN AND CO  Ahmedabad', '5021 D MART KOMPALLY  ', 'PETRO AND AGROWAYS    ', 'COMPASS GROUP INDIA SU', 'PAY*WWW MANAPPURAM COM', 'RAJ ENTERPRISES  ', 'LAKHBIR AUTOMOBILES   ', 'MCDONALDS   ', 'NATHU MAL AHUJA AND SO', 'COCO GOMTINAGAR. ', '4155 DMART MOSHI ', '5014 D MART  ', 'BALAJI GRAND BAZAR    ', 'PURNIMA MOTORS   AHMEDABAD', 'PAZHAMUDIR  ', 'METRO CASH AND CARRY I', 'DOMINOS', 'GOOGLE WORKSPACE 224092000', '3812 D Mart ANANDANAND', 'ABHINANDAN FUELS ', 'BHAVANI AUTO TRADERS  ', 'P  SUBBARAMAIAH  ', 'MODEL SHOP  ', '4049 DMART VIDYAVIHAR ', 'K M SUCHAK AND CONAVI MUMB', 'MODEL SHOP  ', 'RAZ*ROSMERTA SAFETY SYW ', 'A G AGENCY  ', 'GARG DASTAK ', 'IMMANUEL AGENCY  ', 'MCDONALDS   ', 'RSP*NYKAA   ', 'MBV MOTOR FUELS  ', '4521 D MART INDORE    INDORE', 'POORVIKA MOBILES ', '3917 D MART ADAJAN    ', '5608 D MART HENNUR    ', 'K S BAKERS  ', 'RSP*BOB CREDIT CARDS  ', 'HDFC STANDARD LIFE  UN ...
